# %%
from transformers import RobertaTokenizerFast, EncoderDecoderModel
from transformers import get_linear_schedule_with_warmup
from transformers.tokenization_utils import BatchEncoding
import pandas as pd
import torch
from rouge_score import rouge_scorer
from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset
import numpy as np
import matplotlib.pyplot as plt
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"

# %%
# !nvidia-smi
# Out:
# Tue Mar 19 03:19:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-PCIE-40GB          On  | 00000000:27:00.0 Off |                    0 |
# | N/A   30C    P0              37W / 250W |  39385MiB / 40960MiB |     14%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-PCIE-40GB          On  | 00000000:A3:00.0 Off |                    0 |
# | N/A   28C    P0              38W / 250W |  16896MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-PCIE-40GB          On  | 00000000:C3:00.0 Off |                    0 |
# | N/A   30C    P0              35W / 250W |  30234MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    721248      C   python3                                    1110MiB |
# |    0   N/A  N/A   1237067      C   python3                                     574MiB |
# |    0   N/A  N/A   2278040      C   /bin/python3                              30754MiB |
# |    0   N/A  N/A   3958283      C   python                                     1058MiB |
# |    0   N/A  N/A   4119620      C   python                                     5852MiB |
# |    1   N/A  N/A    603342      C   python3                                    9466MiB |
# |    1   N/A  N/A   2278040      C   /bin/python3                                414MiB |
# |    1   N/A  N/A   3958283      C   python                                     1170MiB |
# |    1   N/A  N/A   4119620      C   python                                     5814MiB |
# |    2   N/A  N/A    828278      C   python3                                   23562MiB |
# |    2   N/A  N/A   2278040      C   /bin/python3                                414MiB |
# |    2   N/A  N/A   3958283      C   python                                     1014MiB |
# |    2   N/A  N/A   4119620      C   python                                     5212MiB |
# +---------------------------------------------------------------------------------------+

# %%
model_name = "mrm8488/camembert2camembert_shared-finetuned-french-summarization"
model = EncoderDecoderModel.from_pretrained(model_name)
tokenizer = RobertaTokenizerFast.from_pretrained(model_name)

device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
model.to(device)
model.config.pad_token_id = tokenizer.pad_token_id
model.eval()
# Out:
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# EncoderDecoderModel(
#   (encoder): CamembertModel(
#     (embeddings): CamembertEmbeddings(
#       (word_embeddings): Embedding(32005, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): CamembertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x CamembertLayer(
#           (attention): CamembertAttention(
#             (self): CamembertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): CamembertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): CamembertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): CamembertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): CamembertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): CamembertForCausalLM(
#     (roberta): CamembertModel(
#       (embeddings): CamembertEmbeddings(
#         (word_embeddings): Embedding(32005, 768, padding_idx=1)
#         (position_embeddings): Embedding(514, 768, padding_idx=1)
#         (token_type_embeddings): Embedding(1, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): CamembertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x CamembertLayer(
#             (attention): CamembertAttention(
#               (self): CamembertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): CamembertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (crossattention): CamembertAttention(
#               (self): CamembertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): CamembertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): CamembertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): CamembertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (lm_head): CamembertLMHead(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (decoder): Linear(in_features=768, out_features=32005, bias=True)
#     )
#   )
# )

# %%
# print the number of parameters

num_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {num_params}")
# Out:
# Number of parameters: 139612933

# %%
def tokenize_text(text: pd.Series) -> BatchEncoding:
    tokens = tokenizer(
        text.tolist(),
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=514,
    )

    return tokens

class SummaryDataset(Dataset):
    def __init__(self, encodings, summaries):
        self.encodings = encodings
        self.summaries = summaries
    
    def __getitem__(self, idx):
        item = {key: val[idx].clone().detach() for key, val in self.encodings.items()}
        item['labels'] = self.summaries['input_ids'][idx].clone().detach()
        return item

    def __len__(self):
        return len(self.summaries['input_ids'])

# %%
train_df = pd.read_csv('data/train.csv')
validation_df = pd.read_csv('data/validation.csv')
# longest title is 967 words

df = train_df

input_encodings = tokenize_text(df['text'])
summary_encodings = tokenize_text(df['titles'])

dataset = SummaryDataset(input_encodings, summary_encodings)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# %%
# def find_lr(model, dataloader, device, init_value=1e-8, final_value=10., beta=0.98):
#     num = len(dataloader) - 1
#     mult = (final_value / init_value) ** (1/num)
#     lr = init_value
#     optimizer = AdamW(model.parameters(), lr=lr)
#     model.train()
#     avg_loss = 0.
#     best_loss = 0.
#     batch_num = 0
#     losses = []
#     log_lrs = []
#     for batch in dataloader:
#         batch_num += 1
#         optimizer.param_groups[0]['lr'] = lr
#         input_ids = batch['input_ids'].to(device)
#         attention_mask = batch['attention_mask'].to(device)
#         labels = batch['labels'].to(device)

#         optimizer.zero_grad()
#         outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
#         loss = outputs.loss

#         # Compute the smoothed loss
#         avg_loss = beta * avg_loss + (1-beta) * loss.item()
#         smoothed_loss = avg_loss / (1 - beta**batch_num)

#         # Stop if the loss is exploding
#         if batch_num > 1 and smoothed_loss > 4 * best_loss:
#             break

#         # Record the best loss
#         if smoothed_loss < best_loss or batch_num == 1:
#             best_loss = smoothed_loss

#         # Store the values
#         losses.append(smoothed_loss)
#         log_lrs.append(np.log10(lr))

#         # Do the SGD step
#         loss.backward()
#         optimizer.step()

#         # Update the lr for the next step
#         lr *= mult

#     plt.plot(log_lrs, losses)
#     plt.xlabel('Log10 Learning rate')
#     plt.ylabel('Loss')
#     plt.show()

# # Assuming model and dataloader are defined and initialized
# find_lr(model, dataloader, device)

# %%
def camembert2_summary(encodings, batch_size: int = 8) -> list:
    input_ids = encodings['input_ids']
    attention_mask = encodings['attention_mask']
    summaries = []
    # tokenizer.src_lang = "fr_XX"
    model.eval()

    for i in tqdm(range(0, input_ids.size(0), batch_size)):
        batch_input_ids = input_ids[i:i+batch_size].to(device)
        batch_attention_mask = attention_mask[i:i+batch_size].to(device)

        summary_tokens = model.generate(
            input_ids=batch_input_ids,
            attention_mask=batch_attention_mask,
            max_length=150,
            num_beams=4,
            early_stopping=True
        )

        batch_summaries = [tokenizer.decode(g, skip_special_tokens=True) for g in summary_tokens]
        summaries.extend(batch_summaries)

    return summaries

# %%
def score_summaries(predicted_summary: pd.Series, reference_summary: pd.Series):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = []
    for i in tqdm(range(len(predicted_summary))):
        score = scorer.score(predicted_summary[i], reference_summary[i])[
            'rougeL'][2]
        scores.append(score)
    avg_score = sum(scores) / len(scores)

    return avg_score

# %%
def validation_test(val_df, verbose=True, n=100):
    input_encodings = tokenize_text(val_df['text'][:n])
    summaries = camembert2_summary(input_encodings)
    reference_summaries = val_df['titles'][:n]
    rouge_score = score_summaries(summaries, reference_summaries)
    if verbose:
        print(f"Rouge score: {rouge_score}")
    return rouge_score

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=7e-5)
validation_test(validation_df)


# Then inside your training loop, after optimizer.step(), add:


model.train()
starting_epoch = 0
num_epochs = 6
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(dataloader) * num_epochs)

for epoch in range(starting_epoch, starting_epoch + num_epochs):
    epoch_loss = 0
    for batch in tqdm(dataloader):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        scheduler.step()

        epoch_loss += loss.item()


    print(f"Epoch {epoch+1}: Loss {epoch_loss / len(dataloader)}")
    # save every epoch
    checkpoint_path = f"./checkpoints/model_checkpoint_epoch_{epoch+1}_7e-5_linear_decay_1024tkn.pt"
    torch.save(model.state_dict(), checkpoint_path)

    # validation step
    model.eval()
    validation_test(validation_df)
    model.train()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [844,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [96,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [851,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1290: indexSelectLargeIndex: block: [839,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
#   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> optimizer = torch.optim.Adam(model.parameters(), lr=7e-5)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> validation_test(validation_df)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> # Then inside your training loop, after optimizer.step(), add:
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> model.train()
#
# /home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb Cell 11 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def validation_test(val_df, verbose=True, n=100):
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     input_encodings = tokenize_text(val_df['text'][:n])
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     summaries = camembert2_summary(input_encodings)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     reference_summaries = val_df['titles'][:n]
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     rouge_score = score_summaries(summaries, reference_summaries)
#
# /home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> batch_input_ids = input_ids[i:i+batch_size].to(device)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> batch_attention_mask = attention_mask[i:i+batch_size].to(device)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> summary_tokens = model.generate(
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     input_ids=batch_input_ids,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     attention_mask=batch_attention_mask,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     max_length=150,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>     num_beams=4,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     early_stopping=True
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> batch_summaries = [tokenizer.decode(g, skip_special_tokens=True) for g in summary_tokens]
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu4/home/infres/mdaychman-23/inf582-proj/camembert2camembert_shared-finetuned-french-summarization.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> summaries.extend(batch_summaries)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/transformers/generation/utils.py:1413, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1405         logger.warning(
#    1406             "A decoder-only architecture is being used, but right-padding was detected! For correct "
#    1407             "generation results, please set `padding_side='left'` when initializing the tokenizer."
#    1408         )
#    1410 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1411     # if model is encoder decoder encoder_outputs are created
#    1412     # and added to `model_kwargs`
# -> 1413     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1414         inputs_tensor, model_kwargs, model_input_name
#    1415     )
#    1417 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1418 if self.config.is_encoder_decoder:
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/transformers/generation/utils.py:518, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     516 encoder_kwargs["return_dict"] = True
#     517 encoder_kwargs[model_input_name] = inputs_tensor
# --> 518 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     520 return model_kwargs
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/transformers/models/camembert/modeling_camembert.py:881, in CamembertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     874 # Prepare head mask if needed
#     875 # 1.0 in head_mask indicate we keep the head
#     876 # attention_probs has shape bsz x n_heads x N x N
#     877 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     878 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     879 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 881 embedding_output = self.embeddings(
#     882     input_ids=input_ids,
#     883     position_ids=position_ids,
#     884     token_type_ids=token_type_ids,
#     885     inputs_embeds=inputs_embeds,
#     886     past_key_values_length=past_key_values_length,
#     887 )
#     888 encoder_outputs = self.encoder(
#     889     embedding_output,
#     890     attention_mask=extended_attention_mask,
#    (...)
#     898     return_dict=return_dict,
#     899 )
#     900 sequence_output = encoder_outputs[0]
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/transformers/models/camembert/modeling_camembert.py:144, in CamembertEmbeddings.forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     142 embeddings = inputs_embeds + token_type_embeddings
#     143 if self.position_embedding_type == "absolute":
# --> 144     position_embeddings = self.position_embeddings(position_ids)
#     145     embeddings += position_embeddings
#     146 embeddings = self.LayerNorm(embeddings)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/modules/sparse.py:163, in Embedding.forward(self, input)
#     162 def forward(self, input: Tensor) -> Tensor:
# --> 163     return F.embedding(
#     164         input, self.weight, self.padding_idx, self.max_norm,
#     165         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/inf582-proj/inf582-proj/lib/python3.10/site-packages/torch/nn/functional.py:2237, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2231     # Note [embedding_renorm set_grad_enabled]
#    2232     # XXX: equivalent to
#    2233     # with torch.no_grad():
#    2234     #   torch.embedding_renorm_
#    2235     # remove once script supports set_grad_enabled
#    2236     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2237 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: CUDA error: device-side assert triggered
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
def generate_test_summary(test_df):
    input_encodings = tokenize_text(test_df['text'])
    summaries = camembert2_summary(input_encodings)
    submission_df = pd.DataFrame([[i, summary] for i, summary in enumerate(summaries)],
                                  columns=['ID', 'titles'])
    submission_df.to_csv('submission.csv', index=False)

# %%
test_df = pd.read_csv('data/test.csv')
generate_test_summary(test_df)

# %%
validation_test(validation_df, n=1500)

# %%
# load a model
# model.load_state_dict(torch.load("checkpoints/model_checkpoint_epoch_1.pt"))

# %%
input_encodings = tokenize_text(validation_df['text'][:8])

# %%
summaries = camembert2_summary(input_encodings)
# summaries = camembert2_summary(test_tensor['input_ids'], test_tensor['attention_mask'])

# %%
summaries

# %%
validation_df['titles'][:8].tolist()

# %%
score_summaries(summaries, validation_df['titles'])

# %%
validation_df['text'][5]

# %%
summaries[5]

# %%
validation_df['titles'][0]
